# %%
#crawl data url from search X key

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import json

#modify
PATH = 'F:\slide\chromedriver-win64\chromedriver.exe'
username = "CoiNguyn443321"
password = "123456coi"

# List of target URLs : tự cho
urls = ['https://twitter.com/search?q=elon musk&src=typed_query&f=user','https://twitter.com/search?q=tax&src=typed_query&f=user','https://twitter.com/search?q=money&src=typed_query&f=user'
,'https://twitter.com/search?q=usuk&src=typed_query&f=user', 'https://twitter.com/search?q=india%20musk&src=typeahead_click&f=user','https://twitter.com/search?q=ukrainer&src=typeahead_click&f=user','https://twitter.com/search?q=world&src=typeahead_click&f=user','https://twitter.com/search?q=war&src=typeahead_click&f=user']
driver = webdriver.Chrome(PATH)

# Login to Twitter
driver.get("https://twitter.com/login")
time.sleep(15)

result_list = []
for target_url in urls:

    driver.get(target_url)
    time.sleep(10)
    scroll_down_count = 5  # Change this to the number of times you want to scroll down
    for _ in range(scroll_down_count):
    # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let the page load more content
        time.sleep(7)
        resp = driver.page_source
        soup = BeautifulSoup(resp, 'html.parser')
    #find username
        for user in soup.find_all("div", {"data-testid":"cellInnerDiv"}):
            try:
                username = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("a", {"class": "css-4rbku5 css-18t94o4 css-1dbjc4n r-1loqt21 r-1wbh5a2 r-dnmrzs r-1ny4l3l"}).text
                userurl = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("div", {"class": "css-901oao css-1hf3ou5 r-1bwzh9t r-18u37iz r-37j5jr r-1wvb978 r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}).text
            except:
                pass
            result_list.append({ "username": username, "useurl": userurl})

    
#     try:
#         o['username'] = soup.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("div", {"class": "css-1dbjc4n r-1wbh5a2 r-dnmrzs r-1ny4l3l"}).text
#     except:
#         o["profile_name"] = None
    
#     result_list.append(o)
#   print(result_list)
# Save data to JSON file
   
filename = "twitter_profile_url11.json"
with open(filename, 'a', encoding='utf-8') as jsonfile:
    json.dump(result_list, jsonfile, ensure_ascii=False, indent=4)



print(f"Data saved to {filename}")
driver.quit()
# Out:
# C:\Users\nguye\AppData\Local\Temp\ipykernel_18932\4179902706.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
# Data saved to twitter_profile_url11.json

# %%
import pandas as pd
df = pd.read_json("twitter_profile_url11.json", encoding="utf-8")

# Loại bỏ các mục trùng lặp dựa trên cột "useurl"
filenew = df.drop_duplicates(subset="useurl", keep="first")

# Ghi DataFrame mới vào một tệp JSON
filenew.to_json("profile_url101.json", orient="records", force_ascii=False, indent=4)

# %%
#crawl data profile X from user url

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import json

PATH = 'F:\slide\chromedriver-win64\chromedriver.exe'
#user
#password


# Specify the path to your JSON file
json_file_path = r'C:\Users\nguye\OneDrive - Hanoi University of Science and Technology\code\bigdata\twitter_profile_url3.json'

# Read the JSON file
with open(json_file_path, 'r', encoding='utf-8') as file:
    user_list = json.load(file)

# userurls = [user_data['useurl'].lstrip('@') for user_data in user_list]
# Extracting useurls and removing '@' using list comprehension
urls = ['https://twitter.com/' + user_data['useurl'].lstrip('@') for user_data in user_list]

# Print the result
print(urls)

#urls = ["https://twitter.com/wojespn"]#, "https://twitter.com/hisman2", "https://twitter.com/Crypto_Crayak","https://twitter.com/ndycuong1"]

driver = webdriver.Chrome(PATH)

# Login to Twitter
driver.get("https://twitter.com/login")
time.sleep(15)

result_list = []

for target_url in urls:
    o = {}
    twitte=[]
    
#     driver = webdriver.Chrome(PATH)
    
    driver.get(target_url)
    time.sleep(20)
    scroll_down_count = 1  # Change this to the number of times you want to scroll down
    for _ in range(scroll_down_count):
    # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let the page load more content
        time.sleep(5)
    
    resp = driver.page_source
    
    soup = BeautifulSoup(resp, 'html.parser')

#get name
    name=[]
    nameurl=[]
    try:
        user= soup.find("div",{"data-testid":"UserName"})
        try:
            username = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("a", {"class": "css-4rbku5 css-18t94o4 css-1dbjc4n r-1loqt21 r-1wbh5a2 r-dnmrzs r-1ny4l3l"}).text
            userurl = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("div", {"class": "css-901oao css-1hf3ou5 r-1bwzh9t r-18u37iz r-37j5jr r-1wvb978 r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}).text
        except:
            pass  
    except:
        pass
    try:
        o["profile_name"] = username
        o["profile_id"] = userurl
    except:
        pass
#get intro

    try:
        o["profile_bio"] = soup.find("div", {"data-testid": "UserDescription"}).text
    except:
        o["profile_bio"] = None

    profile_header = soup.find("div", {"data-testid": "UserProfileHeader_Items"})
#get some details
    try:
        o["profile_category"] = profile_header.find("span", {"data-testid": "UserProfessionalCategory"}).text
    except:
        o["profile_category"] = None

    try:
        o["profile_website"] = profile_header.find('a')['href']
    except:
        o["profile_website"] = None

    try:
        o["profile_joining_date"] = profile_header.find("span", {"data-testid": "UserJoinDate"}).text
    except:
        o["profile_joining_date"] = None

    try:
        o["profile_following"] = soup.find_all("a", {"class": "css-4rbku5 css-18t94o4 css-901oao r-1nao33i r-1loqt21 r-37j5jr r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"})[0].find("span", {"class": "css-901oao css-16my406 r-1nao33i r-poiln3 r-1b43r93 r-b88u0q r-1cwl3u0 r-bcqeeo r-qvutc0"}).text
    except:
        o["profile_following"] = None

    try:
        o["profile_followers"] = soup.find_all("a", {"class": "css-4rbku5 css-18t94o4 css-901oao r-1nao33i r-1loqt21 r-37j5jr r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"})[1].find("span", {"class": "css-901oao css-16my406 r-1nao33i r-poiln3 r-1b43r93 r-b88u0q r-1cwl3u0 r-bcqeeo r-qvutc0"}).text
    except:
        o["profile_followers"] = None

    try:
        o["is_verifed"] = bool(soup.find("svg", {"data-testid": "icon-verified"}))
    except:
        o["is_verifed"] = False

# Extract location information
    try:
        #location_section = soup.find("span", {"class": "css-901oao css-16my406 r-1bwzh9t r-4qtqp9 r-poiln3 r-1b7u577 r-bcqeeo r-qvutc0"})[1].find("span",{"class":"css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0"}).text
        o["profile_location"] = soup.find("span", {"data-testid":"UserLocation"}).text
            #     location_parts = location_section.find_all("span", recursive=False)
    #     o["profile_location"] = location_parts[0].text.strip()
    except:
        o["profile_location"] = None
        
#get tweet
    scroll_down_count = 5  # Change this to the number of times you want to scroll down
    for _ in range(scroll_down_count):
    # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let the page load more content
        time.sleep(10)
        resp = driver.page_source
    
        soup = BeautifulSoup(resp, 'html.parser')
        
        try:
            for post in soup.find_all("div",{"data-testid":"cellInnerDiv"}):
                try:
                    is_reposted= bool(post.find("a",{"class":"css-4rbku5 css-18t94o4 css-901oao r-1bwzh9t r-1loqt21 r-37j5jr r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}))
                except:
                    is_reposted:None

                try:
                    content= post.find("div",{"data-testid":"tweetText"}).text
                except:
                    content: None
                try:
                    owner= post.find("div",{"class":"css-901oao css-1hf3ou5 r-1bwzh9t r-18u37iz r-37j5jr r-1wvb978 r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}).text
                except:
                    owner:None
                try:
                    datetime= post.find("time")["datetime"]
                except:
                    time:None
                twitte.append({'is_reposted':is_reposted,'owner':owner,'time':datetime,'content':content})
        except:
            pass
        ####
        # Append the result to the list
    o["twitte"]= twitte
    
#get follower and following
    following_url=target_url+'/following'
    driver.get(following_url)
    time.sleep(15)
    scroll_down_count = 2  # Change this to the number of times you want to scroll down
    for _ in range(scroll_down_count):
    # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let the page load more content
        time.sleep(5)

    resp = driver.page_source
    soup = BeautifulSoup(resp, 'html.parser')
    
    block = soup.find_all("div", {"data-testid":"cellInnerDiv"})
    followings=[]  
    
    for user in block:
        try:
            #username = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("a", {"class": "css-4rbku5 css-18t94o4 css-1dbjc4n r-1loqt21 r-1wbh5a2 r-dnmrzs r-1ny4l3l"}).text
            userurl = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("div", {"class": "css-901oao css-1hf3ou5 r-1bwzh9t r-18u37iz r-37j5jr r-1wvb978 r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}).text
            followings.append( userurl)
        except:
            pass        
    o['following']=followings
#---        
    follower_url=target_url+'/followers'
    driver.get(follower_url)
    time.sleep(15)
    scroll_down_count = 2  # Change this to the number of times you want to scroll down
    for _ in range(scroll_down_count):
    # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let the page load more content
        time.sleep(5)

    resp = driver.page_source
    soup = BeautifulSoup(resp, 'html.parser')
    
    block = soup.find_all("div", {"data-testid":"cellInnerDiv"})
    followers=[]
    
    
    for user in block:
        try:
            #username = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("a", {"class": "css-4rbku5 css-18t94o4 css-1dbjc4n r-1loqt21 r-1wbh5a2 r-dnmrzs r-1ny4l3l"}).text
            userurl = user.find("div", {"class": "css-1dbjc4n r-1adg3ll r-1ny4l3l"}).find("div", {"class": "css-901oao css-1hf3ou5 r-1bwzh9t r-18u37iz r-37j5jr r-1wvb978 r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-qvutc0"}).text
            followers.append( userurl)
        except:
            pass       
    o['followers']=followers

#store all in4 to list
    
    result_list.append(o)


# Save data to JSON file
filename = "twitter_profile_data.json"
with open(filename, 'a', encoding='utf-8') as jsonfile:
    json.dump(result_list, jsonfile, ensure_ascii=False, indent=4)

print(f"Data saved to {filename}")
driver.quit()
# Out:
# ['https://twitter.com/metansangames', 'https://twitter.com/MettaWorld37', 'https://twitter.com/MetaforDevs', 'https://twitter.com/metamulawallet', 'https://twitter.com/___meta___', 'https://twitter.com/MetaQuestVR', 'https://twitter.com/AfuwapeKazeem', 'https://twitter.com/MetaQuestHelp', 'https://twitter.com/MetaMask', 'https://twitter.com/WZStatsGG', 'https://twitter.com/MetaApesGame', 'https://twitter.com/fb_engineering', 'https://twitter.com/meta_arg', 'https://twitter.com/AIatMeta', 'https://twitter.com/MetaNewsroom', 'https://twitter.com/metaformers', 'https://twitter.com/MetaGalaxy_org', 'https://twitter.com/GREEN_META_HQ', 'https://twitter.com/OthersideMeta', 'https://twitter.com/MetaQuestGaming', 'https://twitter.com/META_STARx', 'https://twitter.com/MetaRaces_io', 'https://twitter.com/MetaworldMTW', 'https://twitter.com/MMATNEWS', 'https://twitter.com/THENFTSTAR', 'https://twitter.com/METAPCs', 'https://twitter.com/_MetaEarth_', 'https://twitter.com/meta_pool', 'https://twi
# ...
